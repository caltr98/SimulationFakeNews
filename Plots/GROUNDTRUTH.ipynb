# %%
  # %matplotlib inline
  import math
  import numpy as np
  import pandas as pd
  import scipy.stats as stats
  import matplotlib.pyplot as plt
  import matplotlib.pyplot as plt
  import numpy as np
  import random
  import seaborn as sns
  import matplotlib.cm as cm

  from matplotlib.ticker import MaxNLocator
  from matplotlib.pyplot import figure
  from sklearn.preprocessing import MinMaxScaler
  from sklearn.preprocessing import LabelEncoder
  from sklearn.preprocessing import PowerTransformer, RobustScaler, QuantileTransformer, MinMaxScaler
  from sklearn.cluster import KMeans
  from sklearn.metrics import silhouette_score
  from sklearn.model_selection import StratifiedShuffleSplit
  from math import pi
  from sklearn.decomposition import PCA
  from matplotlib.colors import ListedColormap
  from mpl_toolkits.mplot3d import Axes3D
  from sklearn.manifold import TSNE
  from sklearn.metrics import pairwise_distances
  from sklearn.neighbors import NearestNeighbors
  from sklearn.cluster import DBSCAN
  from scipy.cluster.hierarchy import linkage, dendrogram
  from scipy.stats import mode
  from scipy.spatial.distance import pdist
  from sklearn.cluster import AgglomerativeClustering
  from collections import defaultdict
  from collections import defaultdict
  from scipy.stats import pearsonr

# %%
cd /home/cal/analysisResults/
# Out:
# /home/cal/analysisResults

# %%
def plot_sir_data(df, step=10, title='Changes in Susceptible, Infectious, Recovered'):
    # Pivot the DataFrame to have 'Epoch' as index and 'State' as columns
    df_pivot = df.pivot(index='Epoch', columns='State', values='Count')

    # Determine the maximum y-value for setting the y-axis limit
    max_value = df_pivot.max().max()

    # Downsample the DataFrame to reduce the number of points
    df_pivot_reduced = df_pivot.iloc[::step, :]

    # Plotting the data
    plt.figure(figsize=(6, 3))
    plt.plot(df_pivot_reduced.index, df_pivot_reduced['Susceptible'], marker='o', label='Susceptible')
    plt.plot(df_pivot_reduced.index, df_pivot_reduced['Infectious'], marker='v', label='Infectious')
    plt.plot(df_pivot_reduced.index, df_pivot_reduced['Recovered'], marker='*', label='Recovered')

    # Set y-axis to start from 0
    plt.ylim(0, max_value + 10)

    # Increase font sizes for labels and title
    plt.xlabel('Epoch', fontsize=18)
    plt.ylabel('Count', fontsize=18)
    plt.title(title, fontsize=10)
    plt.legend(fontsize=10)
    plt.grid(True)

    # Increase font size for ticks
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)

    plt.show()

# %% [markdown]
# **Average infected, susceptible, recovered with 100 Users and 0 Checkers**

# %%
df_data = pd.read_csv('./0CheckersGTSK/Epochs.csv')

# %%
df_data
# Out:
#      Epoch        State  Count
# 0        0  Susceptible     36
# 1        0   Infectious     63
# 2        0    Recovered      0
# 3        1  Susceptible     19
# 4        1   Infectious     49
# ..     ...          ...    ...
# 295     98   Infectious     36
# 296     98    Recovered     36
# 297     99  Susceptible     27
# 298     99   Infectious     36
# 299     99    Recovered     36
#
# [300 rows x 3 columns]

# %%
plot_sir_data(df_data,title='GT states in Susceptible, Infectious, Recovered in 10 trials with 100 Users,0 Checkers')

# %%
df_100users0checkersUsers = pd.read_csv('./0CheckersGTSK/UserTrial.csv')

# %%
df_100users0checkersPosts = pd.read_csv('./0CheckersGTSK/Post.csv')

# %% [markdown]
# **Average infected, susceptible, recovered with 100 Users and 20 Checkers**

# %%
df_data = pd.read_csv('./20CheckersGT/Epochs.csv')

# %%
plot_sir_data(df_data,title='GT states in Susceptible, Infectious, Recovered for 20 trials with 100 Users,20 Checkers')

# %%
df_100users10checkersUsers = pd.read_csv('./20CheckersGT/UserTrial.csv')

# %%
df_100users10checkersPosts = pd.read_csv('./20CheckersGT/Post.csv')

# %% [markdown]
# **Average infected, susceptible, recovered in 5 trials with 100 Users and 40 Checkers**

# %%
df_data = pd.read_csv('./40CheckersGT/Epochs.csv')

# %%
plot_sir_data(df_data,title='GT states in Susceptible, Infectious, Recovered with 100 Users,40 Checkers')

# %%
df_100users30checkersUsers = pd.read_csv('./40CheckersGT/UserTrial.csv')

# %%
df_100users30checkersPosts = pd.read_csv('./40CheckersGT/Post.csv')

# %% [markdown]
# **Average infected, susceptible, recovered 100 Users and 60 Checkers**

# %%
df_data = pd.read_csv('./60CheckersGT/Epochs.csv')

# %%
df_data
# Out:
#      Epoch        State  Count
# 0        0  Susceptible     18
# 1        0   Infectious     21
# 2        0    Recovered     60
# 3        1  Susceptible     10
# 4        1   Infectious     18
# ..     ...          ...    ...
# 295     98   Infectious     13
# 296     98    Recovered     73
# 297     99  Susceptible     12
# 298     99   Infectious     13
# 299     99    Recovered     73
#
# [300 rows x 3 columns]

# %%
plot_sir_data(df_data,title='GT states in Susceptible, Infectious, Recovered with 100 Users,60 Checkers')

# %%
df_100users50checkersUsers = pd.read_csv('./60CheckersGT/UserTrial.csv')

# %%
df_100users50checkersPosts = pd.read_csv('./60CheckersGT/Post.csv')

# %% [markdown]
# **Average infected, susceptible with 100 Users and 80 Checkers**

# %%
df_data = pd.read_csv('./80CheckersGT/Epochs.csv')

# %%
df_data
# Out:
#      Epoch        State  Count
# 0        0  Susceptible      9
# 1        0   Infectious     10
# 2        0    Recovered     80
# 3        1  Susceptible      5
# 4        1   Infectious      9
# ..     ...          ...    ...
# 295     98   Infectious      6
# 296     98    Recovered     86
# 297     99  Susceptible      6
# 298     99   Infectious      6
# 299     99    Recovered     86
#
# [300 rows x 3 columns]

# %%
plot_sir_data(df_data,title='GT states in Susceptible, Infectious, Recovered with 100 Users,80 Checkers')

# %%
df_100users70checkersUsers = pd.read_csv('./60CheckersGT/UserTrial.csv')

# %%
df_100users70checkersPosts = pd.read_csv('./60CheckersGT/Post.csv')

# %% [markdown]
# # UsersAggregates

# %%
df_100users0checkersUsers['source'] = 'df_100users0checkersUsers'
df_100users10checkersUsers['source'] = 'df_100users10checkersUsers'
df_100users30checkersUsers['source'] = 'df_100users30checkersUsers'
df_100users50checkersUsers['source'] = 'df_100users50checkersUsers'
df_100users70checkersUsers['source'] = 'df_100users70checkersUsers'

# Concatenate DataFrames
df_merged = pd.concat([df_100users0checkersUsers,df_100users10checkersUsers,df_100users30checkersUsers,df_100users50checkersUsers, df_100users70checkersUsers], ignore_index=True)

# %%
df_merged
# Out:
#    Total Trials  Average Total Shared Posts  Average Total Fake Shared Posts  \
# 0          1000                     2999.15                         1001.640
# 1          1000                     2999.76                          805.744
# 2          1000                     2999.41                          604.952
# 3          1000                     2998.96                          404.570
# 4          1000                     2998.96                          404.570
#
#    Average Total ReShared Posts  Average Total Fake ReShared Posts  \
# 0                       6995.32                            977.857
# 1                       6993.95                            520.335
# 2                       6994.29                            249.168
# 3                       6994.85                             95.834
# 4                       6994.85                             95.834
#
#    Average Total Recovered  Average Total Infectious  \
# 0                   36.472                    36.520
# 1                   48.657                    28.531
# 2                   61.112                    20.850
# 3                   73.704                    13.859
# 4                   73.704                    13.859
#
#    Average Total Susceptible  Std Dev Total Shared Posts  \
# 0                     27.008                     46.2189
# 1                     22.812                     46.3559
# 2                     18.038                     45.7071
# 3                     12.437                     47.2530
# 4                     12.437                     47.2530
#
#    Std Dev Total Fake Shared Posts  Std Dev Total ReShared Posts  \
# 0                          470.575                       46.2121
# 1                          372.647                       46.3169
# 2                          276.970                       45.8782
# 3                          184.440                       47.3697
# 4                          184.440                       47.3697
#
#    Std Dev Total Fake ReShared Posts  Std Dev Total Recovered  \
# 0                           742.6170                 15.26120
# 1                           366.4170                 12.38520
# 2                           166.8320                  9.44349
# 3                            63.0952                  6.52368
# 4                            63.0952                  6.52368
#
#    Std Dev Total Infectious  Std Dev Total Susceptible  \
# 0                   17.7978                   14.12770
# 1                   13.6081                   11.40340
# 2                   10.1677                    9.10651
# 3                    6.8674                    6.33246
# 4                    6.8674                    6.33246
#
#                        source
# 0   df_100users0checkersUsers
# 1  df_100users10checkersUsers
# 2  df_100users30checkersUsers
# 3  df_100users50checkersUsers
# 4  df_100users70checkersUsers

# %% [markdown]
# | Averages ± stdev/checkers-skillsmatch   | Average Total ReShared Posts   | Average Total Fake ReShared Posts   | Average Total Recovered<br>(End) | Average Total Infectious<br>(End) | Average Total Susceptible<br>(End) |
# |-----------------------------------------|--------------------------------|-------------------------------------|----------------------------------|-----------------------------------|------------------------------------|
# | --------------------------------------- | ------------------------------ | ----------------------------------- | -------------------------        | --------------------------        | ----------------------------       |
# | 10-1 Dataset                            | 69959.5 ± 134.4                | 18214.0 ± 483.9                     | 23.4 ± 3.9                       | 59.8 ± 6.9                        | 16.8 ± 5.7                         |
# | 10-3 Dataset                            | 69999.2 ± 94.4                 | 15990.9 ± 510.4                     | 26.4 ± 2.9                       | 54.1 ± 4.5                        | 19.5 ± 4.9                         |
# | 30-1 Dataset                            | 69988.2 ± 152.4                | 12309.2 ± 455.9                     | 37.7 ± 3.5                       | 45.6 ± 6.8                        | 16.7 ± 4.0                         |
# | 50.1 Dataset                            | 69951.7 ± 110.2                | 7199.8 ± 487.3                      | 52.0 ± 7.3                       | 34.8 ± 9.7                        | 13.2 ± 4.6                         |
# | 70-1 Dataset                            | 70028.7 ± 128.5                | 2766.3 ± 397.1                      | 74.5 ± 2.7                       | 16.3 ± 4.1                        | 9.2 ± 3.0                          |
# | 0 Ground Truth                          | 69938.5 ± 184.6                | 22521.9 ± 275.4                     | 20.2 ± 3.4                       | 61.4 ± 7.6                        | 18.4 ± 5.8                         |
# | 10 Ground Truth                         | 69964.7 ± 89.9                 | 15984.6 ± 673.8                     | 26.6 ± 3.7                       | 53.5 ± 4.4                        | 19.9 ± 4.7                         |
# | 30 Ground Truth                         | 69979.3 ± 120.0                | 7660.6 ± 276.2                      | 40.8 ± 2.5                       | 43.1 ± 4.6                        | 16.1 ± 3.7                         |
# | 50 Ground Truth                         | 69972.9 ± 124.5                | 3072.0 ± 299.1                      | 56.7 ± 1.5                       | 27.1 ± 3.1                        | 16.2 ± 3.6                         |
# | 70 Ground Truth                         | 70029.6 ± 143.0                | 1028.0 ± 150.3                      | 74.4 ± 2.2                       | 15.4 ± 2.1                        | 10.2 ± 2.7                         |

# %% [markdown]
# #PostAggregates

# %%
df_100users0checkersPosts
# Out:
#                Metric      Average  StandardDeviation
# 0       NumberOfPosts  2999.150000          46.242000
# 1            MaxDepth    23.086000           2.614080
# 2          MaxBreadth     5.011000           0.495100
# 3                Size     2.713000           4.283100
# 4        AverageDepth     2.455880           0.043575
# 5      AverageBreadth     0.801459           0.026282
# 6         AverageSize     3.295230           0.063754
# 7          StdDevSize     4.468850           0.410265
# 8   NumberOfFakePosts  1001.640000         470.811000
# 9        MaxDepthFake    10.801000           2.855790
# 10     MaxBreadthFake     3.723000           0.645514
# 11           SizeFake     1.890160           0.303757
# 12  NumberOfTruePosts  1997.510000         469.843000
# 13       MaxDepthTrue    23.086000           2.614080
# 14     MaxBreadthTrue     4.989000           0.507086
# 15           SizeTrue     4.049400           0.417761

# %%
df_100users0checkersPosts= df_100users0checkersPosts.set_index('Metric').T
df_100users10checkersPosts = df_100users10checkersPosts.set_index('Metric').T
df_100users30checkersPosts = df_100users30checkersPosts.set_index('Metric').T
df_100users50checkersPosts = df_100users50checkersPosts.set_index('Metric').T
df_100users70checkersPosts = df_100users70checkersPosts.set_index('Metric').T

# %%
df_100users0checkersPosts['source'] = 'df_100users0checkersUsers'
df_100users10checkersPosts['source'] = 'df_100users10checkersUsers'
df_100users30checkersPosts['source'] = 'df_100users30checkersUsers'
df_100users50checkersPosts['source'] = 'df_100users50checkersUsers'
df_100users70checkersPosts['source'] = 'df_100users70checkersUsers'

# Concatenate DataFrames
df_merged = pd.concat([df_100users0checkersPosts,df_100users10checkersPosts,df_100users30checkersPosts,df_100users50checkersPosts, df_100users70checkersPosts], ignore_index=False)

# %%
df_merged
# Out:
# Metric             NumberOfPosts  MaxDepth  MaxBreadth     Size  AverageDepth  \
# Average                2999.1500  23.08600    5.011000  2.71300      2.455880
# StandardDeviation        46.2420   2.61408    0.495100  4.28310      0.043575
# Average                2999.7600  23.19000    5.035000  2.40900      2.446910
# StandardDeviation        46.3791   2.63834    0.505995  3.94782      0.044986
# Average                2999.4100  23.05300    5.041000  2.48800      2.450610
# StandardDeviation        45.7299   2.58009    0.491488  3.73012      0.041899
# Average                2998.9600  23.00600    5.038000  2.68500      2.462550
# StandardDeviation        47.2766   2.70320    0.482482  4.21349      0.039012
# Average                2998.9600  23.00600    5.038000  2.68500      2.462550
# StandardDeviation        47.2766   2.70320    0.482482  4.21349      0.039012
#
# Metric             AverageBreadth  AverageSize  StdDevSize  NumberOfFakePosts  \
# Average                  0.801459     3.295230    4.468850           1001.640
# StandardDeviation        0.026282     0.063754    0.410265            470.811
# Average                  0.791411     3.299270    4.713590            805.744
# StandardDeviation        0.028493     0.061683    0.234190            372.834
# Average                  0.790527     3.310030    4.770300            604.952
# StandardDeviation        0.028557     0.054140    0.239608            277.109
# Average                  0.801274     3.318320    4.698620            404.570
# StandardDeviation        0.026601     0.052621    0.228861            184.532
# Average                  0.801274     3.318320    4.698620            404.570
# StandardDeviation        0.026601     0.052621    0.228861            184.532
#
# Metric             MaxDepthFake  MaxBreadthFake  SizeFake  NumberOfTruePosts  \
# Average               10.801000        3.723000  1.890160           1997.510
# StandardDeviation      2.855790        0.645514  0.303757            469.843
# Average                7.849000        3.272000  1.598110           2194.020
# StandardDeviation      2.102530        0.634365  0.186334            372.776
# Average                5.782000        2.787000  1.385540           2394.460
# StandardDeviation      1.420030        0.604977  0.113869            279.333
# Average                4.193000        2.207000  1.223850           2594.390
# StandardDeviation      0.966791        0.538926  0.068354            190.403
# Average                4.193000        2.207000  1.223850           2594.390
# StandardDeviation      0.966791        0.538926  0.068354            190.403
#
# Metric             MaxDepthTrue  MaxBreadthTrue  SizeTrue  \
# Average                23.08600        4.989000  4.049400
# StandardDeviation       2.61408        0.507086  0.417761
# Average                23.19000        5.034000  3.967540
# StandardDeviation       2.63834        0.505073  0.374543
# Average                23.05300        5.041000  3.820600
# StandardDeviation       2.58009        0.491488  0.278390
# Average                23.00600        5.038000  3.655160
# StandardDeviation       2.70320        0.482482  0.182283
# Average                23.00600        5.038000  3.655160
# StandardDeviation       2.70320        0.482482  0.182283
#
# Metric                                 source
# Average             df_100users0checkersUsers
# StandardDeviation   df_100users0checkersUsers
# Average            df_100users10checkersUsers
# StandardDeviation  df_100users10checkersUsers
# Average            df_100users30checkersUsers
# StandardDeviation  df_100users30checkersUsers
# Average            df_100users50checkersUsers
# StandardDeviation  df_100users50checkersUsers
# Average            df_100users70checkersUsers
# StandardDeviation  df_100users70checkersUsers

# %% [markdown]
# |   |     | Averages ± stdev/checkers-skillsmatch   | NumberOfPosts          | NumberOfFakePosts     | NumberOfTruePosts     |
# |---|-----|-----------------------------------------|------------------------|-----------------------|-----------------------|
# |   | --- | --------------------------------------- | ---------------------- | --------------------- | --------------------- |
# |   |     | 10-1 Dataset                            | 30033.9 ± 140.0        | 15365.8 ± 113.9       | 14668.1 ± 107.6       |
# |   |     | 10-3 Dataset                            | 29995.1 ± 97.8         | 14930.7 ± 118.4       | 15064.4 ± 74.9        |
# |   |     | 30-1 Dataset                            | 30005.0 ± 160.8        | 12471.1 ± 200.3       | 17533.9 ± 119.7       |
# |   |     | 50.1 Dataset                            | 30043.6 ± 115.0        | 9132.8 ± 190.1        | 20910.8 ± 215.7       |
# |   |     | 70-1 Dataset                            | 29963.4 ± 135.7        | 5331.2 ± 147.3        | 24632.2 ± 221.5       |
# |   |     | 0 Ground Truth                          | 30056.8 ± 192.2        | 16866.6 ± 159.8       | 13190.2 ± 145.2       |
# |   |     | 10 Ground Truth                         | 30030.7 ± 96.7         | 14869.4 ± 129.5       | 15161.3 ± 96.8        |
# |   |     | 30 Ground Truth                         | 30012.9 ± 127.8        | 11332.6 ± 101.7       | 18680.3 ± 104.5       |
# |   |     | 50 Ground Truth                         | 30021.9 ± 129.8        | 7921.8 ± 88.2         | 22100.1 ± 110.0       |
# |   |     | 70 Ground Truth                         | 29964.0 ± 151.1        | 4679.6 ± 64.2         | 25284.4 ± 143.7       |

# %% [markdown]
# | Averages ± stdev/checkers-skillsmatch   | TreeMaxDepthFake   | TreeMaxBreadthFake | TreeSizeFake       | TreeMaxDepthTrue   | TreeMaxBreadthTrue | TreeSizeTrue       |
# |-----------------------------------------|--------------------|--------------------|--------------------|--------------------|--------------------|--------------------|
# | --------------------------------------- | ------------------ | ------------------ | ------------------ | ------------------ | ------------------ | ------------------ |
# | 10-1 Dataset                            | 18.3 ± 2.16        | 4.8 ± 0.63         | 2.19 ± 0.03        | 27.2 ± 1.55        | 5.5 ± 0.53         | 4.40 ± 0.04        |
# | 10-3 Dataset                            | 16.0 ± 2.67        | 4.8 ± 0.63         | 2.07 ± 0.03        | 25.8 ± 1.48        | 5.7 ± 0.48         | 4.33 ± 0.04        |
# | 30-1 Dataset                            | 18.2 ± 1.69        | 4.4 ± 0.52         | 1.99 ± 0.03        | 27.9 ± 1.79        | 5.8 ± 0.42         | 4.21 ± 0.03        |
# | 50.1 Dataset                            | 20.0 ± 2.79        | 4.7 ± 0.48         | 1.79 ± 0.05        | 27.6 ± 2.01        | 5.9 ± 0.32         | 3.95 ± 0.01        |
# | 70-1 Dataset                            | 20.1 ± 2.47        | 4.4 ± 0.70         | 1.52 ± 0.07        | 27.7 ± 1.57        | 5.7 ± 0.67         | 3.71 ± 0.02        |
# | 0 Ground Truth                          | 18.6 ± 1.78        | 5.3 ± 0.48         | 2.34 ± 0.02        | 27.2 ± 1.48        | 5.6 ± 0.52         | 4.46 ± 0.04        |
# | 10 Ground Truth                         | 14.9 ± 1.20        | 4.7 ± 0.48         | 2.07 ± 0.04        | 27.5 ± 2.88        | 5.6 ± 0.52         | 4.43 ± 0.06        |
# | 30 Ground Truth                         | 10.9 ± 1.73        | 4.1 ± 0.57         | 1.68 ± 0.02        | 28.5 ± 2.37        | 5.7 ± 0.48         | 4.26 ± 0.04        |
# | 50 Ground Truth                         | 7.2 ± 0.63         | 3.7 ± 0.48         | 1.39 ± 0.04        | 26.4 ± 1.51        | 5.9 ± 0.57         | 3.99 ± 0.04        |
# | 70 Ground Truth                         | 5.7 ± 0.67         | 2.8 ± 0.42         | 1.22 ± 0.03        | 28.0 ± 2.36        | 5.8 ± 0.42         | 3.71 ± 0.02        |
